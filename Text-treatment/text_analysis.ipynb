# %%
import pandas as pd
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
df = pd.read_parquet('../mda_text.parquet')

# %%
tokenizer = AutoTokenizer.from_pretrained("yiyanghkust/finbert-tone")
model = AutoModelForSequenceClassification.from_pretrained("yiyanghkust/finbert-tone")

# Set model to eval mode
model.eval()

# Define sentiment labels
labels = ["negative", "neutral", "positive"]

# Define prediction function
def get_sentiment(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
        probs = torch.nn.functional.softmax(outputs.logits, dim=1)
        predicted = torch.argmax(probs, dim=1).item()
        return labels[predicted]

# Apply to DataFrame (this may take a few minutes depending on size)
df["sentiment"] = df["text"].apply(get_sentiment)

# Optional: Save the result
df.to_csv("sentiment_annotated.csv", index=False)
# Out:
# config.json:   0%|          | 0.00/533 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/226k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 20
#      17         return labels[predicted]
#      19 # Apply to DataFrame (this may take a few minutes depending on size)
# ---> 20 df["sentiment"] = df["text"].apply(get_sentiment)
#      22 # Optional: Save the result
#      23 df.to_csv("sentiment_annotated.csv", index=False)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
# ...

# %%
df['company_conformed_name'].value_counts()
# Out:
# company_conformed_name
# SANTANDER DRIVE AUTO RECEIVABLES LLC    22
# Ally Auto Assets LLC                    12
# HYUNDAI ABS FUNDING LLC                 11
# AFS SenSub Corp.                        11
# CAPITAL AUTO RECEIVABLES LLC            10
#                                         ..
# SAGA COMMUNICATIONS INC                  1
# Neuralstem, Inc.                         1
# REPROS THERAPEUTICS INC.                 1
# INTER PARFUMS INC                        1
# AMARU INC                                1
# Name: count, Length: 7241, dtype: int64

# %%
df['report_year'].value_counts()
# Out:
# report_year
# 2015    6467
# 2016    1684
# 2014     131
# 2013      24
# 2012      10
# 2011       2
# 2010       2
# 2008       1
# 2009       1
# Name: count, dtype: int64
